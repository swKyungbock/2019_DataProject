# %% [markdown]
# # Day2 : 데이터의 시각화(matplotlib)

# %% [markdown]
# ## #1.matplotlib 그래프 알아보기

# %% [markdown]
# - python에서 그래프를 그리기 위한 라이브러리
# - matplotlib.pyplot : matlab 스타일의 그래프를 그리기 위한 서브 라이브러리
# - import matplotlib.pyplot as plt : plt(별칭)으로 matplotlib.pyplot을 임포트 함.

# %% [markdown]
# ### 1-1.선그래프 그리기

# %%
import matplotlib.pyplot as plt 
data=[1,2,3,4]
plt.plot(data)
plt.show()

# %% [markdown]
# ### 1-1.선그래프 그리기-x축, y축 값 설정

# %%
import matplotlib.pyplot as plt
xdata=[1,2,3,4]
ydata=[10,40,30,50]
plt.plot(xdata,ydata)
plt.show()

# %% [markdown]
# ### 1-2. 그래프꾸미기-마커, 선색, 선스타일 변경하기

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[10,40,30,50],'rs--')
plt.show()

# %% [markdown]
# ### 1-3. 제목 넣기(영어)

# %%
import matplotlib.pyplot as plt
plt.plot(['A','B','C','D'],[10,40,30,50],'ob-.')
plt.title('Chart Title')
plt.show()

# %% [markdown]
# ### 1-3. 제목 넣기(한글)

# %%
import matplotlib.pyplot as plt
plt.plot(['A','B','C','D'],[10,40,30,50],'ob-.')
plt.title('차트 제목')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(['A','B','C','D'],[10,40,30,50],'ob-.')
plt.rcParams['font.family']='Malgun Gothic' #한글처리
plt.title('차트 제목')
plt.show()

# %% [markdown]
# ### 1-4. 2개의 선 그래프를 그리고 범례넣기

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.plot([4,3,2,1])

plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],'rs-.',label='A')
plt.plot([4,3,2,1],'*b--',label='B')
plt.legend()
plt.rcParams['font.family']='Malgun Gothic'
plt.title('A와 B의 변화과정')
plt.show()

# %% [markdown]
# ## #2.matplotlib을 이용하여 다양한 그래프 그려보기

# %% [markdown]
# ### 2-1.bar 그래프 그리기(수직)

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family']='Malgun Gothic'
plt.title('bar 그래프')
plt.bar([1,2,3,4],[10,30,20,50])
plt.show()

# %% [markdown]
# ### 2-1.bar 그래프 그리기(수평)

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family']='Malgun Gothic'
plt.title('수평 bar 그래프')
plt.grid()
plt.barh([1,2,3,4],[10,30,20,50],color='r')
plt.show()

# %% [markdown]
# ### 2-2. 히스토그램 그래프 그리기

# %%
import matplotlib.pyplot as plt
data=[]
import random
for i in range(8) :
    data.append(random.randint(1,10))
print(data)
plt.rcParams['font.family']='Malgun Gothic'
plt.title('랜덤 발생 빈도')
plt.hist(data)
plt.show()
# Out:
# [5, 7, 1, 7, 8, 2, 6, 1]

# %% [markdown]
# ### 2-3. 파이 그래프 그리기

# %%
import matplotlib.pyplot as plt
fruit=['사과','바나나','딸기','오렌지','포도']
result=[7,6,3,2,2]
plt.rcParams['font.family']='Malgun Gothic'
plt.title('좋아하는 선택 과일 결과')
plt.pie(result)
plt.show()

# %%
import matplotlib.pyplot as plt
fruit=['사과','바나나','딸기','오렌지','포도']
result=[7,6,3,2,2]
sum=0
for i in result:
    sum=sum+i
print(sum)
plt.rcParams['font.family']='Malgun Gothic'
plt.rcParams['figure.figsize']=[6,6] #원의 모양을 정원으로 하기 위함
plt.title('좋아하는 선택 과일 결과')
explode_value=(0.1,0,0,0,0)
plt.pie(result, labels=fruit, autopct='%.1f%%',startangle=90,counterclock=False)
plt.show()
# Out:
# 20

# %%
import matplotlib.pyplot as plt
fruit=['사과','바나나','딸기','오렌지','포도']
result=[7,6,3,2,2]
sum=0
for i in result:
    sum=sum+i
print(sum)
plt.rcParams['font.family']='Malgun Gothic'
plt.title('좋아하는 선택 과일 결과')
explode_value=(0.1,0,0,0,0)
plt.pie(result, labels=fruit, autopct='%.1f%%',startangle=90,counterclock=False,explode=explode_value,shadow=True)
plt.show()
# Out:
# 20

# %% [markdown]
# ### 2-3. 산점도 그래프 그리기

# %%
import matplotlib.pyplot as plt
x=[]
y=[]
size=[]
c=[]
colors=['r','g','b','c','m','k','y']
plt.title('랜덤 좌표, 랜덤 사이즈의 산점도 그래프')
import random
for i in range(100) :
    x.append(random.randint(1,10000))
    y.append(random.randint(1,10000))
    size.append(random.randint(1,1000))
    c.append(random.choice(colors))

plt.scatter(x,y,s=size,c=c,alpha=0.5)
plt.show()

# %% [markdown]
# ## [실습1] 2차원 그래프 그리기

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family']='Malgun Gothic' #한글 처리
plt.rcParams['axes.unicode_minus']=False #마이너스 기호(-) 문제 해결
x=[]
y=[]
for i in range(-100,100) :
    x.append(i)
    y.append(2*i**2)
plt.title('2차원 그래프 그리기')
plt.xlabel('x축')
plt.ylabel('y축')
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## [실습2] 키와 몸무게의 관계를 나타내는 산점도 그래프 그리기

# %%
import matplotlib.pyplot as plt
import csv
plt.rcParams['font.family']='Malgun Gothic'
plt.title('키와 몸무게의 관계')
f=open('./data/height_weight.csv','r')
data=csv.reader(f)
height=[] #키 데이터
weight=[] #몸무게 데이터
size=[]
colors=['r','g','b','c','m','k','y']
next(data)
for row in data :
    height.append(float(row[0]))
    weight.append(float(row[1]))
import random
for i in range(100):
    size.append(random.randint(1,1000))
plt.scatter(height,weight,s=size,c=colors,alpha=0.5)
plt.xlabel('Height(cm)')
plt.ylabel('Weight(kg)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## [실습3] 학생 25명에 대한 수학점수 히스토그램 그리기

# %%
import matplotlib.pyplot as plt
import csv
f=open('./data/math_score.csv','r')
data=csv.reader(f)
next(data)
math=[]
for row in data :
    math.append(int(row[1]))
print(math)
plt.rcParams['font.family']='Malgun Gothic'
plt.title('수학 점수 히스토그램')

plt.grid(True)
plt.hist(math,bins=8)
plt.show()
# Out:
# [76, 82, 84, 83, 90, 86, 85, 92, 72, 71, 100, 87, 81, 76, 94, 78, 81, 60, 79, 69, 74, 87, 82, 68, 79]

# %% [markdown]
# ## [실습4] 운동 시작 전과 후의 윗몸 일으키기 횟수 변화 막대 그래프 그리기

# %%
import matplotlib.pyplot as plt
import csv
f=open('./data/exercise_result.csv','r')
data=csv.reader(f)
next(data)
memberID=[]
before_ex=[]
after_ex=[]
for row in data :
    memberID.append(row[0])
    before_ex.append(int(row[1]))
    after_ex.append(int(row[2]))
dataCnt=len(memberID) #회원의 수
f.close()
index=[]
index2=[]
bar_width=0.4
for i in range(dataCnt) :
    index.append(i)
    index2.append(index[i]+bar_width)
plt.rcParams['font.family']='Malgun Gothic'
plt.title('운동 시작 전와 후의 윗몸 일으키기 횟수 변화')
plt.bar(index,before_ex,tick_label=memberID,color='c',label='before exercise',width=bar_width)
plt.bar(index2,after_ex,color='m',label='after exercise',width=bar_width)
plt.legend()
plt.show()

# %% [markdown]
# ## #3.[project] 우리나라 지역별 인구밀도 scatter graph로 나타내기

# %%
import matplotlib.pyplot as plt
import csv

city=[] #도시이름
lat=[]#위도(latitude)
lon=[]#경도(logitude)
pop_den=[]#2018 인구밀도
f=open('./data/pop_density.csv','r')
data=csv.reader(f)
next(data)
for row in data :
    city.append(row[0])
    lat.append(float(row[1]))
    lon.append(float(row[2]))
    pop_den.append(int(row[-1]))
# print(city)
# print(lat)
# print(lon)
# print(pop_den)
#색 지정
colors=['r','g','b','c','m','k','y']
# x축: 경도, y축 : 위도
plt.rcParams['font.family']='Malgun Gothic'
plt.title('지역별 인구 밀도(2018)')
plt.scatter(lon,lat,s=pop_den,c=colors,alpha=0.5)
plt.xlabel('경도')
plt.ylabel('위도')
for x,y,name in zip(lon, lat, city) :
    plt.text(x,y,name)
plt.show()

# %% [markdown]
# ## #3.[project] 매년 내 생일의 기온 변화 그래프 그리기

# %%
import csv
f=open('./data/seoul_temp.csv','r')
rdata=csv.reader(f)
highTemp=[]
lowTemp=[]
year=[]
for i in range(2002,2020):
    year.append(i)
for row in rdata :
    date=row[0]
    month=date[5:7]
    day=date[8:]
    if(month=='11' and day=='24') :
        highTemp.append(float(row[-1]))
        lowTemp.append(float(row[2]))
f.close()
import matplotlib.pyplot as plt
plt.rcParams['font.family']='Malgun Gothic'
plt.rcParams['axes.unicode_minus']=False
plt.plot(year,highTemp,label='high')
plt.plot(year,lowTemp,label='low')
plt.title('내 생일의 기온 변화(2002~2019년 11월 24일)')
plt.grid(True)
plt.legend()
plt.xlim(2002,2020)
plt.show()
